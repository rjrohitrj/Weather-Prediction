# %%
# Importing the Modules
import dash
import base64
import datetime
import numpy as np
import pandas as pd
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.metrics import mean_squared_error,r2_score
from win32api import GetSystemMetrics
width = GetSystemMetrics(0)
height = GetSystemMetrics(1)

# %%
# Reading the dataset
dataset = pd.read_csv('Climate_data.csv')
dataset.head()
# Out:
#      datetime_utc  conds  dewptm  fog  hail  heatindexm  hum  precipm  \
# 0  19961101-11:00  Smoke       9    0     0         NaN   27      NaN
# 1  19961101-12:00  Smoke      10    0     0         NaN   32      NaN
# 2  19961101-13:00  Smoke      11    0     0         NaN   44      NaN
# 3  19961101-14:00  Smoke      10    0     0         NaN   41      NaN
# 4  19961101-16:00  Smoke      11    0     0         NaN   47      NaN
#
#    pressurem  rain  ...    vism  wdird  wdire  wgustm  windchillm  wspdm  \
# 0     1010.0     0  ...     5.0    280   West     NaN         NaN    7.4
# 1    -9999.0     0  ...     5.0      0  North     NaN         NaN    7.4
# 2    -9999.0     0  ...     5.0      0  North     NaN         NaN    7.4
# 3     1010.0     0  ...     2.0      0  North     NaN         NaN    7.4
# 4     1011.0     0  ...     1.2      0  North     NaN         NaN    0.0
#
#   month  day  year   time
# 0    11    1  1996  11:00
# 1    11    1  1996  12:00
# 2    11    1  1996  13:00
# 3    11    1  1996  14:00
# 4    11    1  1996  16:00
#
# [5 rows x 24 columns]

# %%
# Loading the image of Table Backgound
table_image = base64.b64encode(open('table_img.png', 'rb').read())


# Loading the image of Team Members
team_members = base64.b64encode(open('team_members.png', 'rb').read())

# %%
# App initialization
app = dash.Dash()

# %%
# style for Rows
style_R= {
    'color':'#111111',
    'fontSize': '25px',
    'fontFamily': 'Comic San MS',
    'height': '80px',
}

# style for Header
style_H= {
    'color':'#4d4d80',
    'fontSize': '30px',
    'fontFamily': 'Comic San MS',
    'height':'60px',
    'text-align':'left',
    'width':'50px'
}

# %%
# Setting layout for web page
app.layout = html.Div([
    
    # Background image div
    html.Div(id='background',style= {'width':'100%', 'height':'100%'}),
    
    # Date Picker Componnets div
    html.Div([dcc.DatePickerSingle(id='date-picker', 
                                   date=datetime.datetime.now(),
                                   min_date_allowed=datetime.datetime(1996, 11, 1), 
                                   display_format='DD MMM, YYYY',
                                   placeholder='Select a date',
                                   reopen_calendar_on_clear=True)],
             style={'margin-top':20, 'margin-left':50}),
    
    # Table background image div
    html.Div(html.Img(src='data:image/png;base64,{}'.format(table_image.decode()), 
                      style={'width':350, 'height':400}),
             style= {'width':0, 'height':0, 'margin-top':40, 'margin-left':50}),
    
    # Table for Predicted Temperature div
    html.Div(id='temp_table',
             style={'width': '49%', 'display': 'inline-block','margin-left': 60}),
    
    # Graph of Weekly's Temperature Variation div
    html.Div(id='Graph',
             style={'width': '40%','height':'30%', 'float': 'right', 'display': 'inline-block','margin-right': 50}),
    
    # Image of Team Memgers div
    html.Img(src='data:image/png;base64,{}'.format(team_members.decode()), 
             style={'width':width, 'height':500,'margin-top':80}),
    
    # Dash Component for Changing Background
    dcc.Interval(id='interval-component', interval=1*4000, n_intervals=0)
])


# callback function for date picker object to predict temperature and showing Html Table 
@app.callback(Output('temp_table', 'children'), [Input('date-picker', 'date')])
def update_output(date):
    if date is not None:
        year = int(date[:4])
        month = int(date[5:7])
        day = int(date[8:10])
        d = list()
        d.append(datetime.date(year,month,day))
        for i in range(1,4):
            d.append(d[0] + datetime.timedelta(days=i))
        temp = list()
        for i in range(4):
            temp.append(model_training(d[i]))
            
        # returning a Html Table of predicted temperature    
        return html.Table(
            [html.Tr([html.Th("Date"), html.Th("Temperature")] ,style=style_H)] 
            +
            [html.Tr([html.Td("{:%b %d, %A }".format(d[i])), html.Td(str(temp[i])+'° C', style={'text-align':'right'})],
                     style=style_R) for i in range(4)], 
            style={'width':'30px'})

    
# callback function for Graph     
@app.callback(Output('Graph', 'children'), [Input('date-picker', 'date')])
def update_output(date):
    if date is not None:
        year = int(date[:4])
        month = int(date[5:7])
        day = int(date[8:10])
        d = list()
        for i in range(-14,15,7):
            d.append(datetime.date(year,month,day) + datetime.timedelta(days=i))
        temp = list()
        for i in d:
            temp.append(model_training(i))
        return dcc.Graph(id='example-graph',
                         figure={'data':[{'x': d, 'y': temp, 'type': 'line'}],                           
                                 'layout': {'title':  'WEEKLY TEMPERATURE VARIATION',
                                            'plot_bgcolor': '#DBEC9A',
                                            'paper_bgcolor': '#E9F3C2',
                                            'font':{ 'color': '#0041f2'},
                                            'xaxis':{'title': 'DATE'},
                                            'yaxis':{'title':'TEMPERATURE'}
                                           }
                                }
                        )
    

# Callback function for changing Image    
@app.callback(Output('background', 'children'), [Input('interval-component', 'n_intervals')])
def update_graph_live(n):
    image_filename = 'bg_'+str(int(n%16))+'.png'
    encoded_image = base64.b64encode(open(image_filename, 'rb').read())
    return [html.Img(src='data:image/png;base64,{}'.format(encoded_image.decode()), 
                     style={'width':width, 'height':height})]

# %%
# Training the model for weather predictions
def model_training(date):
    year = date.year
    month = date.month
    day = date.day
    
    # Selecting Appropriate dataset for prediction
    df = dataset[(dataset['month']==month) & (dataset['day']<=day) & (dataset['day']>=day-3)]
    
    # Independent variable data selection
    X = df.iloc[:,[2,6,8,19]].values
    
    # Dependent variable data selection
    y = df.iloc[:,11].values
    
    # spliting data into train and test
    X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.1)
    
    # Model - 1
    # Creating a Simple Linear Regressor and fitting dataset
    lin_reg = LinearRegression()
    lin_reg.fit(X_train, y_train) 
    
    # Model - 2
    # Creating Decision tree Regressor and fitting dataset
    dec_reg = DecisionTreeRegressor(random_state = 0)
    dec_reg.fit(X_train, y_train)
    
    # Model - 3
    # Fitting Random Forest Regression to the dataset
    for_reg = RandomForestRegressor(n_estimators = 10, random_state = 0)
    for_reg.fit(X_train, y_train)

    # predicting on test data
    lin_pred = np.round(lin_reg.predict(X_test)).astype(int)
    dec_pred = np.round(dec_reg.predict(X_test)).astype(int)
    for_pred = np.round(for_reg.predict(X_test)).astype(int)
    
    # Creating datframe of Comparision metrics
    cm = pd.DataFrame({'Actual':y_test, 'Linear_Pred': lin_pred, 'Decision_Pred': dec_pred, 'Forest_Pred': for_pred})

    stat = pd.DataFrame({'Model':['Linear Regressor','Decision Regressor','Forest Regressor'],
                         'Mean squared error': [mean_squared_error(y_test,lin_pred),
                                                mean_squared_error(y_test,dec_pred),
                                                mean_squared_error(y_test,for_pred)],
                        'Root mean squared error': [np.sqrt(mean_squared_error(y_test,lin_pred)),
                                                    np.sqrt(mean_squared_error(y_test,dec_pred)),
                                                    np.sqrt(mean_squared_error(y_test,for_pred))],
                        'R_2 statics': [r2_score(y_test, lin_pred),
                                        r2_score(y_test, dec_pred),
                                        r2_score(y_test, for_pred)]})
    stat = stat.set_index('Model')
    
    print('\n\n',date,'\n----------------------')
    print(cm.head())
    print('\n',stat)
    
    # Calculating the mean values of Independent variables Data
    
    dew=np.mean(X[:,0])                         # Dew point 
    hum=np.mean(X[:,1])                         # Humidty   
    press=np.mean(X[:,2])                       # Pressure 
    windsp=np.mean(X[:,3])                      # Wind speed

    # Creating a 2D numpy array of shape(1, 4)
    test = np.array([dew,hum,press,windsp]).reshape((1,4))
    
    # Predicting a new result
    temperature = for_reg.predict(test)
    
    
    # returning the predicted temperature
    return int(round(*temperature))

# %%
# main 
if __name__ == "__main__":
    app.run_server(debug=False)
# Out:
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [03/Aug/2018 14:21:22] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:21:24] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:21:24] "GET /_dash-dependencies HTTP/1.1" 200 -
#  2018-07-20
# ----------------------
#    Actual  Decision_Pred  Forest_Pred  Linear_Pred
# 0      29             29           29           28
# 1      40             35           37           36
# 2      33             35           35           34
# 3      30             30           30           29
# 4      27             27           27           26
#
#                      Mean squared error  R_2 statics  Root mean squared error
# Model
# Linear Regressor              1.327273     0.880421                 1.152073
# Decision Regressor            1.490909     0.865679                 1.221028
# Forest Regressor              1.000000     0.909907                 1.000000
#
#
#  2018-07-27
# ----------------------
#    Actual  Decision_Pred  Forest_Pred  Linear_Pred
# 0      30             30           30           31
# 1      38             38           39           36
# 2      31             30           30           31
# 3      25             24           25           25
# 4      33             31           32           33
#
#                      Mean squared error  R_2 statics  Root mean squared error
# Model
# Linear Regressor              1.099099     0.897623                 1.048379
# Decision Regressor            0.477477     0.955525                 0.690997
# Forest Regressor              0.315315     0.970630                 0.561529
#
#
#  2018-08-03
# ----------------------
#    Actual  Decision_Pred  Forest_Pred  Linear_Pred
# 0      33             34           33           33
# 1      28             28           28           27
# 2      34             34           34           33
# 3      25             26           26           26
# 4      34             34           34           35
#
#                      Mean squared error  R_2 statics  Root mean squared error
# Model
# Linear Regressor              1.047619     0.898186                 1.023533
# Decision Regressor            1.071429     0.895872                 1.035098
# Forest Regressor              0.678571     0.934052                 0.823754
#
#
#  2018-08-10
# ----------------------
#    Actual  Decision_Pred  Forest_Pred  Linear_Pred
# 0      31             31           31           31
# 1      30             30           30           31
# 2      29             29           29           29
# 3      30             31           31           31
# 4      27             27           27           27
#
#                      Mean squared error  R_2 statics  Root mean squared error
# Model
# Linear Regressor              3.701754     0.428917                 1.923994
# Decision Regressor            0.929825     0.856553                 0.964274
# Forest Regressor              0.719298     0.889031                 0.848115
# 127.0.0.1 - - [03/Aug/2018 14:21:25] "POST /_dash-update-component HTTP/1.1" 200 -
#  2018-08-17
# ----------------------
#    Actual  Decision_Pred  Forest_Pred  Linear_Pred
# 0      33             34           34           33
# 1      31             31           32           33
# 2      29             28           28           30
# 3      27             27           27           28
# 4      34             37           35           35
#
#                      Mean squared error  R_2 statics  Root mean squared error
# Model
# Linear Regressor              1.054545     0.847151                 1.026911
# Decision Regressor            0.545455     0.920940                 0.738549
# Forest Regressor              0.354545     0.948611                 0.595437
#
#
#  2018-08-03
# ----------------------
#    Actual  Decision_Pred  Forest_Pred  Linear_Pred
# 0      26             26           26           26
# 1      30             30           30           30
# 2      28             29           28           29
# 3      30             30           30           30
# 4      31             32           31           32
#
#                      Mean squared error  R_2 statics  Root mean squared error
# Model
# Linear Regressor              0.773810     0.919350                 0.879664
# Decision Regressor            1.202381     0.874682                 1.096531
# Forest Regressor              0.404762     0.957814                 0.636209
#
#
#  2018-08-04
# ----------------------
#    Actual  Decision_Pred  Forest_Pred  Linear_Pred
# 0      29             29           29           29
# 1      26             26           26           25
# 2      34             33           33           33
# 3      34             35           34           34
# 4      34             34           34           33
#
#                      Mean squared error  R_2 statics  Root mean squared error
# Model
# Linear Regressor              1.089286     0.884085                 1.043689
# Decision Regressor            0.892857     0.904987                 0.944911
# Forest Regressor              0.803571     0.914489                 0.896421
# 127.0.0.1 - - [03/Aug/2018 14:21:25] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:21:25] "POST /_dash-update-component HTTP/1.1" 200 -
#  2018-08-05
# ----------------------
#    Actual  Decision_Pred  Forest_Pred  Linear_Pred
# 0      27             27           27           27
# 1      35             34           35           35
# 2      27             27           27           27
# 3      30             30           30           30
# 4      32             33           32           33
#
#                      Mean squared error  R_2 statics  Root mean squared error
# Model
# Linear Regressor              0.750000     0.933619                 0.866025
# Decision Regressor            0.750000     0.933619                 0.866025
# Forest Regressor              0.446429     0.960487                 0.668153
#
#
#  2018-08-06
# ----------------------
#    Actual  Decision_Pred  Forest_Pred  Linear_Pred
# 0      33             35           35           34
# 1      27             27           27           27
# 2      35             35           35           34
# 3      27             27           27           27
# 4      33             34           33           32
#
#                      Mean squared error  R_2 statics  Root mean squared error
# Model
# Linear Regressor              0.781818     0.911592                 0.884205
# Decision Regressor            0.418182     0.952712                 0.646670
# Forest Regressor              0.536364     0.939348                 0.732369
# 127.0.0.1 - - [03/Aug/2018 14:21:25] "GET /favicon.ico HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:21:29] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:21:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:21:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:21:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:21:44] "POST /_dash-update-component HTTP/1.1" 200 -
#  2018-07-23
# ----------------------
#    Actual  Decision_Pred  Forest_Pred  Linear_Pred
# 0      27             28           28           28
# 1      32             32           32           32
# 2      31             31           31           31
# 3      30             30           30           30
# 4      31             31           30           31
#
#                      Mean squared error  R_2 statics  Root mean squared error
# Model
# Linear Regressor              1.063063     0.882662                 1.031049
# Decision Regressor            0.792793     0.912494                 0.890389
# Forest Regressor              0.531532     0.941331                 0.729062
#
#
#  2018-07-30
# ----------------------
#    Actual  Decision_Pred  Forest_Pred  Linear_Pred
# 0      28             29           29           29
# 1      35             35           34           34
# 2      38             38           38           36
# 3      27             27           27           26
# 4      27             27           27           27
#
#                      Mean squared error  R_2 statics  Root mean squared error
# Model
# Linear Regressor              1.180180     0.869487                 1.086361
# Decision Regressor            0.567568     0.937234                 0.753371
# Forest Regressor              0.504505     0.944208                 0.710285
#
#
#  2018-08-06
# ----------------------
#    Actual  Decision_Pred  Forest_Pred  Linear_Pred
# 0      27             27           27           27
# 1      30             30           30           30
# 2      28             28           28           28
# 3      33             33           33           34
# 4      31             31           31           30
#
#                      Mean squared error  R_2 statics  Root mean squared error
# Model
# Linear Regressor              0.809091     0.908419                 0.899495
# Decision Regressor            0.500000     0.943405                 0.707107
# Forest Regressor              0.418182     0.952666                 0.646670
#
#
#  2018-08-13
# ----------------------
#    Actual  Decision_Pred  Forest_Pred  Linear_Pred
# 0      31             31           31           32
# 1      27             27           27           27
# 2      36             36           36           34
# 3      27             27           27           28
# 4      27             27           27           27
#
#                      Mean squared error  R_2 statics  Root mean squared error
# Model
# Linear Regressor              1.052632     0.820267                 1.025978
# Decision Regressor            0.543860     0.907138                 0.737468
# Forest Regressor              0.438596     0.925111                 0.662266
#
#
#  2018-08-20
# ----------------------
#    Actual  Decision_Pred  Forest_Pred  Linear_Pred
# 0      33             33           33           34
# 1      32             32           32           33
# 2      27             26           27           29
# 3      29             29           29           31
# 4      33             33           33           34
#
#                      Mean squared error  R_2 statics  Root mean squared error
# Model
# Linear Regressor              0.858491     0.868940                 0.926548
# Decision Regressor            0.386792     0.940951                 0.621926
# Forest Regressor              0.330189     0.949592                 0.574620
#
#
#  2018-08-06
# ----------------------
#    Actual  Decision_Pred  Forest_Pred  Linear_Pred
# 0      31             31           31           30
# 1      32             32           33           33
# 2      34             34           34           33
# 3      35             34           35           35
# 4      27             27           27           27
#
#                      Mean squared error  R_2 statics  Root mean squared error
# Model
# Linear Regressor              0.681818     0.902533                 0.825723
# Decision Regressor            0.554545     0.920727                 0.744678
# Forest Regressor              0.409091     0.941520                 0.639602
#
#
#  2018-08-07
# ----------------------
#    Actual  Decision_Pred  Forest_Pred  Linear_Pred
# 0      31             30           31           32
# 1      31             31           31           30
# 2      31             31           30           30
# 3      32             32           32           31
# 4      33             33           33           33
#
#                      Mean squared error  R_2 statics  Root mean squared error
# Model
# Linear Regressor              0.944954     0.870808                 0.972088
# Decision Regressor            0.559633     0.923489                 0.748086
# Forest Regressor              0.357798     0.951083                 0.598162
#
#
#  2018-08-08
# ----------------------
#    Actual  Decision_Pred  Forest_Pred  Linear_Pred
# 0      28             28           28           27
# 1      30             31           31           31
# 2      29             29           29           30
# 3      34             35           34           35
# 4      31             31           31           31
#
#                      Mean squared error  R_2 statics  Root mean squared error
# Model
# Linear Regressor              0.935780     0.889384                 0.967357
# Decision Regressor            0.798165     0.905651                 0.893401
# Forest Regressor              0.623853     0.926256                 0.789844
# 127.0.0.1 - - [03/Aug/2018 14:21:44] "POST /_dash-update-component HTTP/1.1" 200 -
#  2018-08-09
# ----------------------
#    Actual  Decision_Pred  Forest_Pred  Linear_Pred
# 0      31             31           31           30
# 1      34             34           34           33
# 2      28             28           28           28
# 3      29             29           29           28
# 4      31             31           31           31
#
#                      Mean squared error  R_2 statics  Root mean squared error
# Model
# Linear Regressor              0.816514     0.879882                 0.903612
# Decision Regressor            0.431193     0.936567                 0.656653
# Forest Regressor              0.394495     0.941965                 0.628089
# 127.0.0.1 - - [03/Aug/2018 14:21:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:21:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:21:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:21:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:22:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:22:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:22:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:22:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:22:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:22:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:22:25] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:22:29] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:22:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:22:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:22:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:22:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:22:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:22:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:22:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:23:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:23:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:23:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:23:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:23:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:23:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:23:25] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:23:29] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:23:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:23:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:23:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:23:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:23:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:23:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:23:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:24:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:24:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:24:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:24:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:24:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:24:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:24:25] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:24:29] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:24:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:24:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:24:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:24:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:24:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:24:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:24:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:25:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:25:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:25:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:25:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:25:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:25:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:25:25] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:25:29] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:25:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:25:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:25:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:25:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:25:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:25:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:25:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:26:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:26:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:26:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:26:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:26:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:26:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:26:25] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:26:29] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:26:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:26:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:26:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:26:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:26:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:26:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:26:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:27:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:27:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:27:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:27:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:27:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:27:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:27:25] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:27:29] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:27:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:27:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:27:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:27:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:27:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:27:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:27:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:28:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:28:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:28:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:28:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:28:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:28:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:28:25] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:28:29] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:28:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:28:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:28:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:28:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:28:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:28:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:28:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:29:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:29:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:29:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:29:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:29:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:29:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:29:25] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:29:29] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:29:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:29:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:29:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:29:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:29:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:29:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:29:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:30:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:30:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:30:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:30:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:30:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:30:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:30:25] "POST /_dash-update-component HTTP/1.1" 200 -
#  2018-08-07
# ----------------------
#    Actual  Decision_Pred  Forest_Pred  Linear_Pred
# 0      29             29           29           29
# 1      33             32           32           33
# 2      27             27           27           27
# 3      30             33           31           30
# 4      33             33           33           33
#
#                      Mean squared error  R_2 statics  Root mean squared error
# Model
# Linear Regressor              0.623853     0.926961                 0.789844
# Decision Regressor            0.568807     0.933406                 0.754193
# Forest Regressor              0.330275     0.961332                 0.574696
#
#
#  2018-08-14
# ----------------------
#    Actual  Decision_Pred  Forest_Pred  Linear_Pred
# 0      27             27           27           27
# 1      36             36           36           36
# 2      30             30           30           31
# 3      34             34           34           33
# 4      33             32           32           33
#
#                      Mean squared error  R_2 statics  Root mean squared error
# Model
# Linear Regressor              0.894737     0.877249                 0.945905
# Decision Regressor            0.885965     0.878452                 0.941257
# Forest Regressor              0.570175     0.921776                 0.755100
#
#
#  2018-08-21
# ----------------------
#    Actual  Decision_Pred  Forest_Pred  Linear_Pred
# 0      26             26           26           26
# 1      31             31           31           30
# 2      34             34           34           33
# 3      33             33           33           33
# 4      34             34           33           33
#
#                      Mean squared error  R_2 statics  Root mean squared error
# Model
# Linear Regressor              1.349057     0.845832                 1.161489
# Decision Regressor            0.660377     0.924533                 0.812636
# Forest Regressor              0.443396     0.949329                 0.665880
#
#
#  2018-08-28
# ----------------------
#    Actual  Decision_Pred  Forest_Pred  Linear_Pred
# 0      34             32           32           34
# 1      30             30           29           30
# 2      30             30           30           29
# 3      29             29           29           29
# 4      30             29           30           31
#
#                      Mean squared error  R_2 statics  Root mean squared error
# Model
# Linear Regressor              1.411215     0.838064                 1.187946
# Decision Regressor            0.785047     0.909916                 0.886029
# Forest Regressor              1.000000     0.885251                 1.000000
# 127.0.0.1 - - [03/Aug/2018 14:30:28] "POST /_dash-update-component HTTP/1.1" 200 -
#  2018-09-04
# ----------------------
#    Actual  Decision_Pred  Forest_Pred  Linear_Pred
# 0      35             35           34           34
# 1      29             29           28           29
# 2      35             36           34           33
# 3      30             30           31           32
# 4      29             29           29           29
#
#                      Mean squared error  R_2 statics  Root mean squared error
# Model
# Linear Regressor              0.927928     0.893317                 0.963290
# Decision Regressor            0.918919     0.894353                 0.958603
# Forest Regressor              0.693694     0.920247                 0.832883
#
#
#  2018-08-21
# ----------------------
#    Actual  Decision_Pred  Forest_Pred  Linear_Pred
# 0      36             38           36           33
# 1      31             31           31           32
# 2      32             34           33           33
# 3      32             32           32           32
# 4      32             34           33           32
#
#                      Mean squared error  R_2 statics  Root mean squared error
# Model
# Linear Regressor              0.971698     0.878588                 0.985747
# Decision Regressor            0.688679     0.913951                 0.829867
# Forest Regressor              0.613208     0.923381                 0.783076
#
#
#  2018-08-22
# ----------------------
#    Actual  Decision_Pred  Forest_Pred  Linear_Pred
# 0      27             27           27           26
# 1      33             33           33           32
# 2      28             29           29           26
# 3      28             28           28           28
# 4      29             29           30           30
#
#                      Mean squared error  R_2 statics  Root mean squared error
# Model
# Linear Regressor              1.913462     0.802963                 1.383279
# Decision Regressor            1.153846     0.881184                 1.074172
# Forest Regressor              0.971154     0.899996                 0.985471
#
#
#  2018-08-23
# ----------------------
#    Actual  Decision_Pred  Forest_Pred  Linear_Pred
# 0      35             36           35           36
# 1      27             27           27           26
# 2      31             31           32           32
# 3      26             26           26           26
# 4      29             29           29           30
# 127.0.0.1 - - [03/Aug/2018 14:30:28] "POST /_dash-update-component HTTP/1.1" 200 -
#                      Mean squared error  R_2 statics  Root mean squared error
# Model
# Linear Regressor              1.264706     0.864436                 1.124591
# Decision Regressor            0.676471     0.927489                 0.822478
# Forest Regressor              0.686275     0.926438                 0.828417
#
#
#  2018-08-24
# ----------------------
#    Actual  Decision_Pred  Forest_Pred  Linear_Pred
# 0      28             28           28           27
# 1      30             29           30           33
# 2      29             29           29           30
# 3      35             33           33           35
# 4      26             26           26           25
#
#                      Mean squared error  R_2 statics  Root mean squared error
# Model
# Linear Regressor                  1.29     0.851415                 1.135782
# Decision Regressor                0.77     0.911310                 0.877496
# Forest Regressor                  0.50     0.942409                 0.707107
# 127.0.0.1 - - [03/Aug/2018 14:30:29] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:30:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:30:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:30:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:30:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:30:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:30:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:30:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:31:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:31:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:31:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:31:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:31:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:31:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:31:25] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:31:29] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:31:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:31:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:31:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:31:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:31:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:31:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:31:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:32:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:32:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:32:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:32:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:32:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:32:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:32:25] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:32:29] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:32:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:32:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:32:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:32:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:32:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:32:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:32:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:33:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:33:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:33:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:33:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:33:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:33:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:33:25] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:33:29] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:33:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:33:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:33:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:33:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:33:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:33:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:33:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:34:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:34:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:34:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:34:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:34:25] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:34:25] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:34:25] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:34:25] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:34:26] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:34:26] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:34:27] "GET /favicon.ico HTTP/1.1" 200 -
#  2018-07-20
# ----------------------
#    Actual  Decision_Pred  Forest_Pred  Linear_Pred
# 0      30             30           30           29
# 1      29             29           29           30
# 2      33             33           33           33
# 3      33             33           33           33
# 4      31             31           32           33
#
#                      Mean squared error  R_2 statics  Root mean squared error
# Model
# Linear Regressor              1.172727     0.858151                 1.082925
# Decision Regressor            0.827273     0.899936                 0.909545
# Forest Regressor              0.745455     0.909832                 0.863397
#
#
#  2018-07-27
# ----------------------
#    Actual  Decision_Pred  Forest_Pred  Linear_Pred
# 0      33             33           33           33
# 1      33             32           32           33
# 2      27             27           27           27
# 3      28             29           29           30
# 4      29             29           29           29
#
#                      Mean squared error  R_2 statics  Root mean squared error
# Model
# Linear Regressor              1.054054     0.894380                 1.026671
# Decision Regressor            0.621622     0.937711                 0.788430
# Forest Regressor              0.387387     0.961182                 0.622405
#
#
#  2018-08-03
# ----------------------
#    Actual  Decision_Pred  Forest_Pred  Linear_Pred
# 0      31             31           31           30
# 1      32             32           32           31
# 2      27             27           27           27
# 3      29             29           29           29
# 4      32             33           32           33
#
#                      Mean squared error  R_2 statics  Root mean squared error
# Model
# Linear Regressor              0.880952     0.907938                 0.938591
# Decision Regressor            0.690476     0.927844                 0.830949
# Forest Regressor              0.488095     0.948993                 0.698638
# 127.0.0.1 - - [03/Aug/2018 14:34:27] "POST /_dash-update-component HTTP/1.1" 200 -
#  2018-08-10
# ----------------------
#    Actual  Decision_Pred  Forest_Pred  Linear_Pred
# 0      27             27           27           27
# 1      33             36           35           34
# 2      31             30           30           30
# 3      27             27           27           27
# 4      34             34           34           35
#
#                      Mean squared error  R_2 statics  Root mean squared error
# Model
# Linear Regressor              0.789474     0.903807                 0.888523
# Decision Regressor            0.798246     0.902739                 0.893446
# Forest Regressor              0.350877     0.957248                 0.592349
#
#
#  2018-08-17
# ----------------------
#    Actual  Decision_Pred  Forest_Pred  Linear_Pred
# 0      32             31           34           34
# 1      25             26           26           26
# 2      29             29           29           29
# 3      27             27           27           26
# 4      30             30           30           29
#
#                      Mean squared error  R_2 statics  Root mean squared error
# Model
# Linear Regressor              1.245455     0.838237                 1.115999
# Decision Regressor            0.972727     0.873660                 0.986269
# Forest Regressor              0.481818     0.937420                 0.694131
#
#
#  2018-08-03
# ----------------------
#    Actual  Decision_Pred  Forest_Pred  Linear_Pred
# 0      26             26           26           26
# 1      27             27           27           27
# 2      27             28           27           28
# 3      33             32           33           33
# 4      28             28           28           29
#
#                      Mean squared error  R_2 statics  Root mean squared error
# Model
# Linear Regressor              0.714286     0.927967                 0.845154
# Decision Regressor            0.833333     0.915962                 0.912871
# Forest Regressor              0.416667     0.957981                 0.645497
#
#
#  2018-08-04
# ----------------------
#    Actual  Decision_Pred  Forest_Pred  Linear_Pred
# 0      29             29           29           28
# 1      32             34           34           33
# 2      28             28           28           28
# 3      34             34           34           33
# 4      26             27           27           27
#
#                      Mean squared error  R_2 statics  Root mean squared error
# Model
# Linear Regressor              0.946429     0.902927                 0.972846
# Decision Regressor            0.375000     0.961537                 0.612372
# Forest Regressor              0.383929     0.960621                 0.619620
# 127.0.0.1 - - [03/Aug/2018 14:34:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:34:27] "POST /_dash-update-component HTTP/1.1" 200 -
#  2018-08-05
# ----------------------
#    Actual  Decision_Pred  Forest_Pred  Linear_Pred
# 0      30             29           30           31
# 1      28             28           28           28
# 2      30             30           30           31
# 3      29             28           28           28
# 4      28             28           28           29
#
#                      Mean squared error  R_2 statics  Root mean squared error
# Model
# Linear Regressor              0.562500     0.934970                 0.750000
# Decision Regressor            0.535714     0.938066                 0.731925
# Forest Regressor              0.375000     0.956646                 0.612372
#
#
#  2018-08-06
# ----------------------
#    Actual  Decision_Pred  Forest_Pred  Linear_Pred
# 0      35             33           33           34
# 1      36             36           36           37
# 2      32             31           33           34
# 3      33             33           33           33
# 4      32             32           32           31
#
#                      Mean squared error  R_2 statics  Root mean squared error
# Model
# Linear Regressor              0.890909     0.889164                 0.943880
# Decision Regressor            0.472727     0.941189                 0.687552
# Forest Regressor              0.427273     0.946844                 0.653661
# 127.0.0.1 - - [03/Aug/2018 14:34:31] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:34:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:34:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:34:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:34:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:34:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:34:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:34:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:35:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:35:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:35:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:35:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:35:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:35:23] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:35:27] "POST /_dash-update-component HTTP/1.1" 200 -
#  2018-07-25
# ----------------------
#    Actual  Decision_Pred  Forest_Pred  Linear_Pred
# 0      30             30           30           30
# 1      34             34           34           33
# 2      30             30           30           30
# 3      30             30           30           31
# 4      34             34           34           34
#
#                      Mean squared error  R_2 statics  Root mean squared error
# Model
# Linear Regressor              0.819820     0.892538                 0.905439
# Decision Regressor            0.972973     0.872463                 0.986394
# Forest Regressor              0.846847     0.888995                 0.920243
#
#
#  2018-08-01
# ----------------------
#    Actual  Decision_Pred  Forest_Pred  Linear_Pred
# 0      32             33           33           33
# 1      33             33           32           32
# 2      27             28           28           28
# 3      27             28           27           29
# 4      30             30           29           30
#
#                      Mean squared error  R_2 statics  Root mean squared error
# Model
# Linear Regressor              1.107143     0.866789                 1.052209
# Decision Regressor            0.571429     0.931246                 0.755929
# Forest Regressor              0.678571     0.918355                 0.823754
#
#
#  2018-08-08
# ----------------------
#    Actual  Decision_Pred  Forest_Pred  Linear_Pred
# 0      29             29           29           29
# 1      27             27           27           27
# 2      29             29           29           29
# 3      28             28           28           27
# 4      33             35           35           35
#
#                      Mean squared error  R_2 statics  Root mean squared error
# Model
# Linear Regressor              0.972477     0.872907                 0.986143
# Decision Regressor            0.688073     0.910076                 0.829502
# Forest Regressor              0.577982     0.924464                 0.760251
#
#
#  2018-08-15
# ----------------------
#    Actual  Decision_Pred  Forest_Pred  Linear_Pred
# 0      32             32           32           31
# 1      29             29           29           29
# 2      35             35           34           34
# 3      27             27           27           28
# 4      30             30           30           30
#
#                      Mean squared error  R_2 statics  Root mean squared error
# Model
# Linear Regressor              1.126126     0.874033                 1.061191
# ...
# Model
# Linear Regressor              0.697248     0.897594                 0.835014
# Decision Regressor            0.412844     0.939365                 0.642529
# Forest Regressor              0.440367     0.935323                 0.663602
# 127.0.0.1 - - [03/Aug/2018 14:35:30] "POST /_dash-update-component HTTP/1.1" 200 -
#  2018-08-10
# ----------------------
#    Actual  Decision_Pred  Forest_Pred  Linear_Pred
# 0      27             27           27           27
# 1      30             30           30           31
# 2      30             30           30           30
# 3      29             29           29           28
# 4      34             34           34           33
#
#                      Mean squared error  R_2 statics  Root mean squared error
# Model
# Linear Regressor              0.885965     0.885164                 0.941257
# Decision Regressor            0.754386     0.902219                 0.868554
# Forest Regressor              0.447368     0.942014                 0.668856
#
#
#  2018-08-11
# ----------------------
#    Actual  Decision_Pred  Forest_Pred  Linear_Pred
# 0      29             30           30           30
# 1      31             31           31           31
# 2      34             34           34           33
# 3      36             36           36           34
# 4      33             34           34           33
#
#                      Mean squared error  R_2 statics  Root mean squared error
# Model
# Linear Regressor              0.663793     0.916986                 0.814735
# Decision Regressor            0.448276     0.943938                 0.669534
# Forest Regressor              0.482759     0.939626                 0.694808
# 127.0.0.1 - - [03/Aug/2018 14:35:31] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:35:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:35:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:35:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:35:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:35:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:35:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:35:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:36:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:36:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:36:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:36:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:36:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:36:23] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:36:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:36:31] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:36:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:36:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:36:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:36:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:36:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:36:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:36:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:37:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:37:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:37:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:37:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:37:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:37:23] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:37:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:37:31] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:37:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:37:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:37:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:37:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:37:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:37:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:37:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:38:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:38:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:38:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:38:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:38:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:38:23] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:38:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:38:31] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:38:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:38:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:38:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:38:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:38:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:38:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:38:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:39:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:39:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:39:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:39:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:39:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:39:23] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:39:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:39:31] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:39:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:39:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:39:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:39:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:39:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:39:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:39:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:40:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:40:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:40:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:40:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:40:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:40:23] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:40:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:40:31] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:40:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:40:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:40:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:40:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:40:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:40:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:40:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:41:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:41:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:41:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:41:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:41:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:41:23] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:41:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:41:31] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:41:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:41:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:41:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:41:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:41:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:41:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:41:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:42:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:42:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:42:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:42:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:42:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:42:23] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:42:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:42:31] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:42:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:42:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:42:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:42:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:42:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:42:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:42:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:43:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:43:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:43:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:43:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:43:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:43:23] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:43:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:43:31] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:43:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:43:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:43:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:43:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:43:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:43:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:43:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:44:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:44:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:44:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:44:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:44:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:44:23] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:44:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:44:31] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:44:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:44:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:44:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:44:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:44:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:44:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:44:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:45:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:45:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:45:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:45:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:45:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:45:23] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:45:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:45:31] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:45:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:45:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:45:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:45:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:45:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:45:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:45:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:46:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:46:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:46:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:46:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:46:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:46:23] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:46:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:46:31] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:46:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:46:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:46:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2018 14:46:47] "POST /_dash-update-component HTTP/1.1" 200 -
